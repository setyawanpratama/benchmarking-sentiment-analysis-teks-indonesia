# %%
import os
import h5py
import time
import warnings
import datetime
import numpy as np
import pandas as pd
from nltk.util import usage

from featureExtraction.lexicon.lexicon import *

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score

# %%
files_clean = os.listdir("../Dataset/Clean")
clean = [x for x in files_clean if (x.lower().endswith(".csv"))]
clean.sort()

DATA_CLEAN = ["../Dataset/Clean/" + x for x in files_clean if (x.lower().endswith(".csv"))]
DATA_CLEAN.sort()
len_clean = len(DATA_CLEAN)

# %%
warnings.filterwarnings("ignore")

# %%
count = 1
fail = 0

f1_list = []
acc_list = []

for i in DATA_CLEAN:
    try:
        print("Running {}/{} ({})".format(count, len_clean, clean[count-1]))
        start_time = time.time()
        
        # Feature Extraction
        result_fe, label, feat_name = run_lexiconVania_tweet(i)
        fe_time = time.time()

        # prepare classifier
        cv = KFold(n_splits=20, random_state=1, shuffle=True)
        logRes = LogisticRegression(random_state=1, max_iter=10000)
        
        # prepare the cross-validation procedure
        acc_score = cross_val_score(logRes, result_fe, label, scoring='f1_micro', cv=cv, n_jobs=-1)
        f1_score = cross_val_score(logRes, result_fe, label, scoring='f1_macro', cv=cv, n_jobs=-1)
        cl_time = time.time()

        print('Accuracy: {} ({:.5f})'.format(np.mean(acc_score), np.std(acc_score)))
        print('F1-Score: {} ({:.5f})'.format(np.mean(f1_score), np.std(f1_score)))
        print('FE Time: {} seconds'.format(fe_time - start_time))
        print('CL time: {} seconds'.format(cl_time - fe_time))
        
        f1_list.append(np.mean(f1_score))
        acc_list.append(np.mean(acc_score))
        count += 1
    except Exception as e:
        count += 1
        fail += 1
        print(i, ": ", e)
        pass
    print("================================================")

print("================================================")
print("Overall Accuracy = {} ({})".format(sum(acc_list)/len(acc_list), np.std(acc_list)))
print("Overall F1-Score = {} ({})".format(sum(f1_list)/len(f1_list), np.std(f1_list)))
print("Failed = {}/{}".format(fail, len_clean))
# Out:
# Running 1/13 (templated_posneg_Dataset_C_HT_4000.csv)
# Accuracy: 0.5599999999999999 (0.03098)
# F1-Score: 0.5395911777545167 (0.03199)
# FE Time: 0.33260679244995117 seconds
# CL time: 2.0156900882720947 seconds
# ================================================
# Running 2/13 (templated_posneg_KicauanBerlabel.csv)
# Accuracy: 0.7357500000000001 (0.07251)
# F1-Score: 0.7269285129563675 (0.07665)
# FE Time: 0.07327580451965332 seconds
# CL time: 1.18843674659729 seconds
# ================================================
# Running 3/13 (templated_posneg_dataset_komentar_instagram_cyberbullying.csv)
# Accuracy: 0.7630263157894737 (0.07541)
# F1-Score: 0.7567458218782759 (0.07361)
# FE Time: 0.07722234725952148 seconds
# CL time: 0.39665770530700684 seconds
# ================================================
# Running 4/13 (templated_posneg_dataset_tweet_sentimen_tayangan_tv.csv)
# Accuracy: 0.8 (0.06124)
# F1-Score: 0.7870099422981709 (0.06285)
# FE Time: 0.03783464431762695 seconds
# CL time: 0.03686857223510742 seconds
# ================================================
# Running 5/13 (templated_posneg_dataset_tweet_sentiment_cellular_service_provider.csv)
# Accuracy: 0.7504761904761905 (0.13550)
# F1-Score: 0.7154609095754607 (0.15537)
# FE Time: 0.027689218521118164 seconds
# CL time: 0.042588233947753906 seconds
# ================================================
# Running 6/13 (templated_posneg_dataset_tweet_sentiment_opini_film.csv)
# Accuracy: 0.7383333333333334 (0.13995)
# F1-Score: 0.7070314652667593 (0.14696)
# FE Time: 0.02887725830078125 seconds
# CL time: 0.040251970291137695 seconds
# ================================================
# Running 7/13 (templated_posneg_dataset_tweet_sentiment_pilkada_DKI_2017.csv)
# Accuracy: 0.6135101010101011 (0.05770)
# F1-Score: 0.5822880173688217 (0.06565)
# FE Time: 0.09959602355957031 seconds
# CL time: 0.043704986572265625 seconds
# ================================================
# Running 8/13 (templated_posneg_hotel.csv)
# Accuracy: 0.8024264529058115 (0.01845)
# F1-Score: 0.8020260474423498 (0.01838)
# FE Time: 1.648493766784668 seconds
# CL time: 0.08381962776184082 seconds
# ================================================
# Running 9/13 (templated_posneg_id-apps-review-sentimentanalysis.csv)
# Accuracy: 0.69 (0.17578)
# F1-Score: 0.657924297924298 (0.19665)
# FE Time: 0.023432254791259766 seconds
# CL time: 0.03940582275390625 seconds
# ================================================
# Running 10/13 (templated_posneg_id-movie-review-sentimentanalysis.csv)
# Accuracy: 0.6460000000000001 (0.07826)
# F1-Score: 0.6404276267474284 (0.07962)
# FE Time: 0.07500314712524414 seconds
# CL time: 0.041422128677368164 seconds
# ================================================
# Running 11/13 (templated_posneg_raw_data_sentiment2.csv)
# Accuracy: 0.5664591080746058 (0.03048)
# F1-Score: 0.4236502801320422 (0.02030)
# FE Time: 0.9216899871826172 seconds
# CL time: 0.07571029663085938 seconds
# ================================================
# Running 12/13 (templated_posnegnet_tweetcleannew600-only.csv)
# Accuracy: 0.45978632478632486 (0.05369)
# F1-Score: 0.4541792733510232 (0.05356)
# FE Time: 0.2738015651702881 seconds
# CL time: 0.06586813926696777 seconds
# ================================================
# Running 13/13 (templated_posnegnet_tweets_tagged_preprocessed.csv)
# Accuracy: 0.6478333333333334 (0.08720)
# F1-Score: 0.3377496989766745 (0.09864)
# FE Time: 0.06157326698303223 seconds
# CL time: 0.05784344673156738 seconds
# ================================================
# ================================================
# Overall Accuracy = 0.6748923969007057 (0.09996822505425908)
# Overall F1-Score = 0.6254625439747838 (0.14221234112239156)
# Failed = 0/13

# %%
count = 1
fail = 0

f1_list = []
acc_list = []

for i in DATA_CLEAN:
    try:
        print("Running {}/{} ({})".format(count, len_clean, clean[count-1]))
        start_time = time.time()
        
        # Feature Extraction
        result_fe, label, feat_name = run_lexiconInset_tweet(i)
        fe_time = time.time()

        # prepare classifier
        cv = KFold(n_splits=20, random_state=1, shuffle=True)
        logRes = LogisticRegression(random_state=1, max_iter=10000)
        
        # prepare the cross-validation procedure
        acc_score = cross_val_score(logRes, result_fe, label, scoring='f1_micro', cv=cv, n_jobs=-1)
        f1_score = cross_val_score(logRes, result_fe, label, scoring='f1_macro', cv=cv, n_jobs=-1)
        cl_time = time.time()

        print('Accuracy: {} ({:.5f})'.format(np.mean(acc_score), np.std(acc_score)))
        print('F1-Score: {} ({:.5f})'.format(np.mean(f1_score), np.std(f1_score)))
        print('FE Time: {} seconds'.format(fe_time - start_time))
        print('CL time: {} seconds'.format(cl_time - fe_time))
        
        f1_list.append(np.mean(f1_score))
        acc_list.append(np.mean(acc_score))
        count += 1
    except Exception as e:
        count += 1
        fail += 1
        print(i, ": ", e)
        pass
    print("================================================")

print("================================================")
print("Overall Accuracy = {} ({})".format(sum(acc_list)/len(acc_list), np.std(acc_list)))
print("Overall F1-Score = {} ({})".format(sum(f1_list)/len(f1_list), np.std(f1_list)))
print("Failed = {}/{}".format(fail, len_clean))
# Out:
# Running 1/13 (templated_posneg_Dataset_C_HT_4000.csv)
# Accuracy: 0.63 (0.02490)
# F1-Score: 0.6281257721734037 (0.02502)
# FE Time: 3.2587954998016357 seconds
# CL time: 0.06906914710998535 seconds
# ================================================
# Running 2/13 (templated_posneg_KicauanBerlabel.csv)
# Accuracy: 0.7661666666666666 (0.08411)
# F1-Score: 0.7463930099227706 (0.09527)
# FE Time: 0.6816651821136475 seconds
# CL time: 0.048259735107421875 seconds
# ================================================
# Running 3/13 (templated_posneg_dataset_komentar_instagram_cyberbullying.csv)
# Accuracy: 0.7136842105263158 (0.11742)
# F1-Score: 0.7070177262575298 (0.12145)
# FE Time: 0.6574971675872803 seconds
# CL time: 0.04853224754333496 seconds
# ================================================
# Running 4/13 (templated_posneg_dataset_tweet_sentimen_tayangan_tv.csv)
# Accuracy: 0.6650000000000001 (0.10618)
# F1-Score: 0.6550217875700277 (0.10859)
# FE Time: 0.30439329147338867 seconds
# CL time: 0.048110008239746094 seconds
# ================================================
# Running 5/13 (templated_posneg_dataset_tweet_sentiment_cellular_service_provider.csv)
# Accuracy: 0.6849999999999998 (0.11470)
# F1-Score: 0.6653843782636353 (0.11800)
# FE Time: 0.1711897850036621 seconds
# CL time: 0.05062985420227051 seconds
# ================================================
# Running 6/13 (templated_posneg_dataset_tweet_sentiment_opini_film.csv)
# Accuracy: 0.6405555555555557 (0.16429)
# F1-Score: 0.6129572510822511 (0.16566)
# FE Time: 0.21088409423828125 seconds
# CL time: 0.04864144325256348 seconds
# ================================================
# Running 7/13 (templated_posneg_dataset_tweet_sentiment_pilkada_DKI_2017.csv)
# Accuracy: 0.6480050505050503 (0.06417)
# F1-Score: 0.6437146244232426 (0.06487)
# FE Time: 0.8508510589599609 seconds
# CL time: 0.04962658882141113 seconds
# ================================================
# Running 8/13 (templated_posneg_hotel.csv)
# Accuracy: 0.74834749498998 (0.01935)
# F1-Score: 0.747923720770829 (0.01975)
# FE Time: 16.009423971176147 seconds
# CL time: 0.11454343795776367 seconds
# ================================================
# Running 9/13 (templated_posneg_id-apps-review-sentimentanalysis.csv)
# Accuracy: 0.7 (0.16733)
# F1-Score: 0.6715270840270839 (0.18424)
# FE Time: 0.17355012893676758 seconds
# CL time: 0.04450082778930664 seconds
# ================================================
# Running 10/13 (templated_posneg_id-movie-review-sentimentanalysis.csv)
# Accuracy: 0.5660000000000001 (0.08697)
# F1-Score: 0.5579976988029333 (0.09003)
# FE Time: 0.714301586151123 seconds
# CL time: 0.05150318145751953 seconds
# ================================================
# Running 11/13 (templated_posneg_raw_data_sentiment2.csv)
# Accuracy: 0.5925059096543572 (0.02288)
# F1-Score: 0.5376944409434203 (0.02300)
# FE Time: 9.323688745498657 seconds
# CL time: 0.08189272880554199 seconds
# ================================================
# Running 12/13 (templated_posnegnet_tweetcleannew600-only.csv)
# Accuracy: 0.4745970695970697 (0.05164)
# F1-Score: 0.46886012620632805 (0.05465)
# FE Time: 2.734360456466675 seconds
# CL time: 0.10101056098937988 seconds
# ================================================
# Running 13/13 (templated_posnegnet_tweets_tagged_preprocessed.csv)
# Accuracy: 0.6357499999999998 (0.09388)
# F1-Score: 0.35685785253705077 (0.11550)
# FE Time: 0.5118520259857178 seconds
# CL time: 0.0843815803527832 seconds
# ================================================
# ================================================
# Overall Accuracy = 0.6512009198073072 (0.07492450171779683)
# Overall F1-Score = 0.6153442671523466 (0.10704234649297739)
# Failed = 0/13

# %%
count = 1
fail = 0

f1_list = []
acc_list = []

for i in DATA_CLEAN:
    try:
        print("Running {}/{} ({})".format(count, len_clean, clean[count-1]))
        start_time = time.time()
        
        # Feature Extraction
        result_fe, label, feat_name = run_lexiconCombined_tweet(i)
        fe_time = time.time()

        # prepare classifier
        cv = KFold(n_splits=20, random_state=1, shuffle=True)
        logRes = LogisticRegression(random_state=1, max_iter=10000)
        
        # prepare the cross-validation procedure
        acc_score = cross_val_score(logRes, result_fe, label, scoring='f1_micro', cv=cv, n_jobs=-1)
        f1_score = cross_val_score(logRes, result_fe, label, scoring='f1_macro', cv=cv, n_jobs=-1)
        cl_time = time.time()

        print('Accuracy: {} ({:.5f})'.format(np.mean(acc_score), np.std(acc_score)))
        print('F1-Score: {} ({:.5f})'.format(np.mean(f1_score), np.std(f1_score)))
        print('FE Time: {} seconds'.format(fe_time - start_time))
        print('CL time: {} seconds'.format(cl_time - fe_time))
        
        f1_list.append(np.mean(f1_score))
        acc_list.append(np.mean(acc_score))
        count += 1
    except Exception as e:
        count += 1
        fail += 1
        print(i, ": ", e)
        pass
    print("================================================")

print("================================================")
print("Overall Accuracy = {} ({})".format(sum(acc_list)/len(acc_list), np.std(acc_list)))
print("Overall F1-Score = {} ({})".format(sum(f1_list)/len(f1_list), np.std(f1_list)))
print("Failed = {}/{}".format(fail, len_clean))
# Out:
# Running 1/13 (templated_posneg_Dataset_C_HT_4000.csv)
# Accuracy: 0.63675 (0.02187)
# F1-Score: 0.6352209450998888 (0.02178)
# FE Time: 3.7427899837493896 seconds
# CL time: 0.09037280082702637 seconds
# ================================================
# Running 2/13 (templated_posneg_KicauanBerlabel.csv)
# Accuracy: 0.7941666666666667 (0.09736)
# F1-Score: 0.7776133543220731 (0.10979)
# FE Time: 0.7569377422332764 seconds
# CL time: 0.06384086608886719 seconds
# ================================================
# Running 3/13 (templated_posneg_dataset_komentar_instagram_cyberbullying.csv)
# Accuracy: 0.7863157894736842 (0.08111)
# F1-Score: 0.7792163633505336 (0.08546)
# FE Time: 0.7205767631530762 seconds
# CL time: 0.05777239799499512 seconds
# ================================================
# Running 4/13 (templated_posneg_dataset_tweet_sentimen_tayangan_tv.csv)
# Accuracy: 0.8100000000000002 (0.07176)
# F1-Score: 0.8012180290071326 (0.07591)
# FE Time: 0.315676212310791 seconds
# CL time: 0.057578325271606445 seconds
# ================================================
# Running 5/13 (templated_posneg_dataset_tweet_sentiment_cellular_service_provider.csv)
# Accuracy: 0.7566666666666666 (0.12687)
# F1-Score: 0.725836615572549 (0.14604)
# FE Time: 0.19277739524841309 seconds
# CL time: 0.0592503547668457 seconds
# ================================================
# Running 6/13 (templated_posneg_dataset_tweet_sentiment_opini_film.csv)
# Accuracy: 0.7883333333333334 (0.14917)
# F1-Score: 0.7657960095460095 (0.16440)
# FE Time: 0.2138526439666748 seconds
# CL time: 0.05890822410583496 seconds
# ================================================
# Running 7/13 (templated_posneg_dataset_tweet_sentiment_pilkada_DKI_2017.csv)
# Accuracy: 0.6703535353535354 (0.06040)
# F1-Score: 0.6663515706514588 (0.06126)
# FE Time: 0.9829480648040771 seconds
# CL time: 0.06105685234069824 seconds
# ================================================
# Running 8/13 (templated_posneg_hotel.csv)
# Accuracy: 0.8268583166332665 (0.01695)
# F1-Score: 0.8266029866560608 (0.01701)
# FE Time: 18.00042223930359 seconds
# CL time: 0.14565396308898926 seconds
# ================================================
# Running 9/13 (templated_posneg_id-apps-review-sentimentanalysis.csv)
# Accuracy: 0.7400000000000001 (0.15620)
# F1-Score: 0.7190096015096016 (0.16464)
# FE Time: 0.19413280487060547 seconds
# CL time: 0.053206682205200195 seconds
# ================================================
# Running 10/13 (templated_posneg_id-movie-review-sentimentanalysis.csv)
# Accuracy: 0.648 (0.07756)
# F1-Score: 0.6413220192516922 (0.08053)
# FE Time: 0.7900331020355225 seconds
# CL time: 0.061293601989746094 seconds
# ================================================
# Running 11/13 (templated_posneg_raw_data_sentiment2.csv)
# Accuracy: 0.5931736285277752 (0.02256)
# F1-Score: 0.5395445731367406 (0.02172)
# FE Time: 10.681810140609741 seconds
# CL time: 0.10819649696350098 seconds
# ================================================
# Running 12/13 (templated_posnegnet_tweetcleannew600-only.csv)
# Accuracy: 0.4790109890109891 (0.04773)
# F1-Score: 0.47565552989135185 (0.04888)
# FE Time: 3.1008737087249756 seconds
# CL time: 0.16107416152954102 seconds
# ================================================
# Running 13/13 (templated_posnegnet_tweets_tagged_preprocessed.csv)
# Accuracy: 0.6419166666666667 (0.08103)
# F1-Score: 0.4061716965849052 (0.13356)
# FE Time: 0.5583736896514893 seconds
# CL time: 0.19436073303222656 seconds
# ================================================
# ================================================
# Overall Accuracy = 0.7055035071025065 (0.09920302101979643)
# Overall F1-Score = 0.6738122534292308 (0.1259420536993294)
# Failed = 0/13
