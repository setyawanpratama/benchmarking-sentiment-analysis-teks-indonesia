# %%
import os
import h5py
import time
import warnings
import datetime
import numpy as np

from featureExtraction.ngram.ngram import *

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score

# %%
files_clean = os.listdir("../Dataset/Clean")
clean = [x for x in files_clean if (x.lower().endswith(".csv"))]
clean.sort()

DATA_CLEAN = ["../Dataset/Clean/" + x for x in files_clean if (x.lower().endswith(".csv"))]
DATA_CLEAN.sort()
len_clean = len(DATA_CLEAN)

# %%
warnings.filterwarnings("ignore")

count = 1
fail = 0

f1_list = []
acc_list = []

# %%
for i in DATA_CLEAN:
    try:
        print("Running {}/{} ({})".format(count, len_clean, clean[count-1]))
        start_time = time.time()
        
        # Feature Extraction
        result_fe, label, feat_name = ngram(i, 2)
        fe_time = time.time()

        # prepare classifier
        cv = KFold(n_splits=20, random_state=1, shuffle=True)
        logRes = LogisticRegression(random_state=1, max_iter=10000)
        
        # prepare the cross-validation procedure
        acc_score = cross_val_score(logRes, result_fe, label, scoring='f1_micro', cv=cv, n_jobs=-1)
        f1_score = cross_val_score(logRes, result_fe, label, scoring='f1_macro', cv=cv, n_jobs=-1)
        cl_time = time.time()

        print('Accuracy: {} ({:.5f})'.format(np.mean(acc_score), np.std(acc_score)))
        print('F1-Score: {} ({:.5f})'.format(np.mean(f1_score), np.std(f1_score)))
        print('FE Time: {} seconds'.format(fe_time - start_time))
        print('CL time: {} seconds'.format(cl_time - fe_time))
        
        f1_list.append(np.mean(f1_score))
        acc_list.append(np.mean(acc_score))
        count += 1
    except Exception as e:
        count += 1
        fail += 1
        print(i, ": ", e)
        pass
    print("================================================")

print("================================================")
print("Overall Accuracy = {} ({})".format(sum(acc_list)/len(acc_list), np.std(acc_list)))
print("Overall F1-Score = {} ({})".format(sum(f1_list)/len(f1_list), np.std(f1_list)))
print("Failed = {}/{}".format(fail, len_clean))
# Out:
# Running 1/13 (templated_posneg_Dataset_C_HT_4000.csv)
# Accuracy: 0.9065 (0.01674)
# F1-Score: 0.9055198168276899 (0.01697)
# FE Time: 0.1340632438659668 seconds
# CL time: 33.589210987091064 seconds
# ================================================
# Running 2/13 (templated_posneg_KicauanBerlabel.csv)
# Accuracy: 0.7784166666666665 (0.08150)
# F1-Score: 0.7499107998214136 (0.08879)
# FE Time: 0.037586212158203125 seconds
# CL time: 2.1010022163391113 seconds
# ================================================
# Running 3/13 (templated_posneg_dataset_komentar_instagram_cyberbullying.csv)
# Accuracy: 0.6117105263157895 (0.10657)
# F1-Score: 0.5401170003857018 (0.11115)
# FE Time: 0.030299663543701172 seconds
# CL time: 0.8012957572937012 seconds
# ================================================
# Running 4/13 (templated_posneg_dataset_tweet_sentimen_tayangan_tv.csv)
# Accuracy: 0.5825 (0.09909)
# F1-Score: 0.5600349088202096 (0.10682)
# FE Time: 0.01628851890563965 seconds
# CL time: 0.45436716079711914 seconds
# ================================================
# Running 5/13 (templated_posneg_dataset_tweet_sentiment_cellular_service_provider.csv)
# Accuracy: 0.6492857142857142 (0.10033)
# F1-Score: 0.5697087792705641 (0.11362)
# FE Time: 0.009772300720214844 seconds
# CL time: 0.2912781238555908 seconds
# ================================================
# Running 6/13 (templated_posneg_dataset_tweet_sentiment_opini_film.csv)
# Accuracy: 0.6683333333333333 (0.15183)
# F1-Score: 0.6241641977303741 (0.15408)
# FE Time: 0.009533166885375977 seconds
# CL time: 0.2907891273498535 seconds
# ================================================
# Running 7/13 (templated_posneg_dataset_tweet_sentiment_pilkada_DKI_2017.csv)
# Accuracy: 0.6591919191919191 (0.07227)
# F1-Score: 0.6541700022067204 (0.07335)
# FE Time: 0.035417795181274414 seconds
# CL time: 2.469844341278076 seconds
# ================================================
# Running 8/13 (templated_posneg_hotel.csv)
# Accuracy: 0.8522919839679357 (0.01166)
# F1-Score: 0.8519737208110069 (0.01168)
# FE Time: 0.6293158531188965 seconds
# CL time: 421.8436062335968 seconds
# ================================================
# Running 9/13 (templated_posneg_id-apps-review-sentimentanalysis.csv)
# Accuracy: 0.62 (0.16613)
# F1-Score: 0.5275243547302371 (0.17960)
# FE Time: 0.07144832611083984 seconds
# CL time: 0.9920406341552734 seconds
# ================================================
# Running 10/13 (templated_posneg_id-movie-review-sentimentanalysis.csv)
# Accuracy: 0.6460000000000001 (0.09319)
# F1-Score: 0.6356016676502106 (0.09991)
# FE Time: 0.033335208892822266 seconds
# CL time: 1.719804286956787 seconds
# ================================================
# Running 11/13 (templated_posneg_raw_data_sentiment2.csv)
# Accuracy: 0.7325405748219898 (0.02345)
# F1-Score: 0.717577765495766 (0.02500)
# FE Time: 0.38271021842956543 seconds
# CL time: 275.64547872543335 seconds
# ================================================
# Running 12/13 (templated_posnegnet_tweetcleannew600-only.csv)
# Accuracy: 0.51993894993895 (0.04636)
# F1-Score: 0.5131489015723071 (0.04820)
# FE Time: 0.15061545372009277 seconds
# CL time: 29.982588052749634 seconds
# ================================================
# Running 13/13 (templated_posnegnet_tweets_tagged_preprocessed.csv)
# Accuracy: 0.7619166666666668 (0.06220)
# F1-Score: 0.5795515992238259 (0.13809)
# FE Time: 0.038829803466796875 seconds
# CL time: 1.2988054752349854 seconds
# ================================================
# ================================================
# Overall Accuracy = 0.6914327950145357 (0.10543023669396412)
# Overall F1-Score = 0.6483848857343097 (0.1198708010277092)
# Failed = 0/13
