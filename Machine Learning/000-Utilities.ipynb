# %%
# !tar chvfz machinelearning.tar.gz *
# Out:
# 000-Utilities.ipynb
# 001-runner unigram.ipynb
# 002-runner bigram.ipynb
# 003-runner trigram.ipynb
# 004-runner tfidf.ipynb
# 005-runner orthography.ipynb
# 006-runner postag.ipynb
# 007a-runner word2vec cbow.ipynb
# 007b-runner word2vec sg.ipynb
# 008-runner fasttext.ipynb
# 009-runner lexicon.ipynb
# 010-runner unigram-ortho.ipynb
# 011-runner unigram-pos.ipynb
# 012-runner unigram-w2v.ipynb
# 013-runner unigram-lexicon.ipynb
# 014-runner ortho-pos.ipynb
# 016-runner ortho-lexicon.ipynb
# 018-runner pos-lexicon.ipynb
# classifier/
# classifier/knn/
# classifier/knn/knn.py
# classifier/logisticRegression/
# classifier/logisticRegression/logisticRegression.py
# classifier/naiveBayes/
# classifier/naiveBayes/naiveBayes.py
# classifier/randomForest/
# classifier/randomForest/randomForest.py
# classifier/svm/
# classifier/svm/svm.py
# classifier/decisionTree/
# classifier/decisionTree/decisionTree.py
# classifier/.ipynb_checkpoints/
# featureExtraction/
# ...
