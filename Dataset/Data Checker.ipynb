# %%
import os
import numpy as np
import pandas as pd

# %%
files_clean = os.listdir("Split/Two_Label/")
files_templated = os.listdir("Split/Two_Label/")

clean = [x for x in files_clean if (x.lower().endswith(".csv"))]
clean.sort()

DATA_CLEAN = ["Split/Two_Label/" + x for x in files_clean if (x.lower().endswith(".csv"))]
DATA_CLEAN.sort()
len_clean = len(DATA_CLEAN)

templated = [x for x in files_templated if (x.lower().endswith(".csv"))]
templated.sort()

DATA_TEMPLATED = ["Split/Two_Label/" + x for x in files_templated if (x.lower().endswith(".csv"))]
DATA_TEMPLATED.sort()
len_templated = len(DATA_TEMPLATED)

range_len = max(len_clean, len_templated)

# %%
count = 1
for i in DATA_TEMPLATED:
    df = pd.read_csv(i, delimiter=";", engine='python', header=None)
    df.dropna()
    class_list = df[1].unique().tolist()
    print("{} --> {}".format(templated[count-1], class_list))
    for i in class_list:
        print("== 1 --> {}".format(len(df[1] == i)))
    count += 1
# Out:
# test_posneg_Dataset_C_HT_4000.csv --> [0, 1]
# == 1 --> 800
# == 1 --> 800
# test_posneg_KicauanBerlabel.csv --> [1, 0]
# == 1 --> 99
# == 1 --> 99
# test_posneg_dataset_komentar_instagram_cyberbullying.csv --> [0, 1]
# == 1 --> 78
# == 1 --> 78
# test_posneg_dataset_tweet_sentimen_tayangan_tv.csv --> [1, 0]
# == 1 --> 80
# == 1 --> 80
# test_posneg_dataset_tweet_sentiment_cellular_service_provider.csv --> [0, 1]
# == 1 --> 59
# == 1 --> 59
# test_posneg_dataset_tweet_sentiment_opini_film.csv --> [0, 1]
# == 1 --> 39
# == 1 --> 39
# test_posneg_dataset_tweet_sentiment_pilkada_DKI_2017.csv --> [0, 1]
# == 1 --> 180
# == 1 --> 180
# test_posneg_hotel.csv --> [0, 1]
# == 1 --> 1998
# == 1 --> 1998
# test_posneg_id-apps-review-sentimentanalysis.csv --> [1, 0]
# == 1 --> 40
# == 1 --> 40
# test_posneg_id-movie-review-sentimentanalysis.csv --> [1, 0]
# == 1 --> 100
# == 1 --> 100
# test_posneg_raw_data_sentiment2.csv --> [1, 0]
# == 1 --> 1490
# == 1 --> 1490
# ...

# %%
len(df[df[label == 1]])
