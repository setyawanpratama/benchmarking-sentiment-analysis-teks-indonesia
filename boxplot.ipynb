# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# data_1 = [56, 73.575, 7630263157894737, 80, 75.04761905, 73.83333333, 61.3510101, 80.24264529, 69, 64.6, 56.64591081, 45.97863248, 64.78333333]
# data_2 = [63, 76.61666667, 71.36842105, 66.5, 68.5, 64.05555556, 64.80050505, 74.8347495, 70, 56.6, 59.25059097, 47.45970696, 63.575]
# data_3 = [63.675, 79.41666667, 78.63157895, 81, 75.66666667, 78.83333333, 67.03535354, 82.68583166, 74, 64.8, 59.31736285, 47.9010989, 64.19166667]
#data_4 = [97.23642288, 84.84333133, 89.52836309, 827.4791722, 81.23679864, 84.16057554, 73.50866723, 91.02332607, 85.2297841, 68.02186703, 82.6896413, 61.40437633, 58.2792035]
#data = [data_1, data_2, data_3, data_4]
# data = [data_1, data_2, data_3]
#data = [data_1, data_2]
#data = [54.30670406, 36.72050083, 48.26778113, 33.82683948, 48.12371, 44.44135276, 49.62076542, 61.25113222, 50.86080586, 50.14709127, 43.49038178, 29.325162, 31.26208982]

data_1 = [97.75, 87.50833333, 85.40789474, 83.5, 82.45238095, 81.88888889, 73.71717172, 91.40825651, 86.5, 69, 85.08323964, 60.77289377, 76.15833333]
data_2 = [97.875, 90.1, 87.68421053, 84.5, 83.45238095, 83.94444444, 73.1489899, 91.47843687, 88, 69.6, 85.20445963, 59.94200244, 76.76666667]
data_3 = [97.925, 90.90833333, 88.18421053, 86.75, 85.11904762, 84.44444444, 75.48989899, 91.54831663, 87.5, 69.6, 85.00291879, 60.71855922, 77.14166667]
data_4 = [97.95, 90.74166667, 87.17105263, 88.5, 82.45238095, 82.94444444, 75.71464646, 91.69877756, 90, 70.6, 85.15066015, 61.42857143, 75.73333333]
data_5 = [72.775, 63.73333333, 60.52631579, 57.75, 55.4047619, 69.16666667, 55.34090909, 65.89276553, 57.5, 51, 64.17718873, 44.59279609, 66.96666667]
data_6 = [95.675, 82.50833333, 85.35526316, 81.25, 76.02380952, 76.38888889, 74.26767677, 87.63272545, 85, 67.4, 77.26948745, 62.03418803, 78.4]
data_7 = [77.825, 84.50833333, 79.39473684, 83.25, 78, 76.33333333, 67.69949495, 83.16663327, 75.5, 66, 65.13188619, 50.495116, 67.43333333]
data_8 = [95.575, 83.24166667, 86.88157895, 84, 77, 78.38888889, 72.26262626, 87.95298597, 88, 67.4, 76.65200063, 60.04700855, 76.975]
data_9 = [64.875, 79.025, 79.14473684, 81.5, 73.95238095, 77.77777778, 66.36111111, 82.93621242, 79.5, 64.6, 59.73370521, 49.83272283, 63.98333333]
data_10 = [95.4, 87.1, 86.67105263, 86.5, 78.69047619, 81.38888889, 75.26515152, 89.00456914, 87.5, 69, 76.96099628, 61.32478632, 77.6]
data = [data_1, data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9, data_10]

# %%
fig = plt.figure(figsize =(13, 5))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title("Persebaran Akurasi Kelompok 6",fontsize=16)
ax.set_xticklabels(['Unigram\n+\nOrtografi', 'Unigram\n+\nPOS Tagging', 'Unigram\n+\nWord2Vec',
                   'Unigram\n+\nLeksikon', 'Ortografi\n+\nPOS Tagging', 'Ortografi\n+\nWord2Vec',
                   'Ortografi\n+\nLeksikon', 'POS Tagging\n+\nWord2Vec', 'POS Tagging\n+\nLeksikon',
                   'Word2Vec\n+\nLeksikon', ], fontsize=14)
ax.set_ylim([0,100])
# Creating plot
style = dict(linewidth=3.0, color='#000000')
style_median = dict(linewidth=3.0, color='#ff0000')
style_box = dict(linewidth=3.0, color='#000000')

bp = ax.boxplot(data, meanline=True, boxprops=style_box, medianprops=style_median, whiskerprops=style, capprops=style, patch_artist=True)

for box in bp['boxes']:
    box.set(facecolor = '#00ff7f')

# show plot
plt.show()
# Out:
# /tmp/ipykernel_16259/3257893781.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Unigram\n+\nOrtografi', 'Unigram\n+\nPOS Tagging', 'Unigram\n+\nWord2Vec',
